# %% [markdown]
# # QUESTION #1
#
# 1. LOAD DATA
# 2. UNDERSTAND THE DATA
# 3. CHECK MISSING VALUES
# 4. FILL MISSING VALUES
# 5. REMOVE DUPLICATES
# 6. FIX DATATYPES
# 7. SAVE CLEANED DATA

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("titanic.csv")
df.columns = df.columns.str.lower()

# %%
df.info()
df.describe()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df = df.drop(columns=['Cabin'])

# %%
# Check for duplicates
df.duplicated().sum()

# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Convert Survived and Pclass to categorical
df["Survived"] = df["Survived"].astype("category")
df["Pclass"] = df["Pclass"].astype("category")

# %%
df.to_csv("titanic_cleaned.csv", index=False)

# %% [markdown]
# # QUESTION 2

# %% [markdown]
# # SURIVAL RATE

# %%
import matplotlib.pyplot as plt

df.groupby('pclass')['survived'].mean().plot(kind='bar', color='blue', edgecolor='black')
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# # INSIGHT
# THE FIRST CLASS HAS A HIGHER SURVIVAL RATE
# - POSSIBLE REASON:
#     - PASSENGER ARE RICH
#     - PASSENGER ARE OLD

# %% [markdown]
# # Age Distribution of Survivors vs Non-Survivors

# %%
df["age"].plot(kind="hist", bins=20, edgecolor="black")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# # INSIGHT
#
# YOUNGER PEOPLE HAS A HIGHER SURVIVAL RATE, I THINK ITS BECAUSE ON THE POLICIES (WOMEN AND CHILDREN FIRST)
